# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import datetime as dt
import scipy.stats as sp
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error,r2_score

# %%
data=pd.read_csv('Testing in Karnataka.csv')

# %%
data.head()
# Out:
#          Date  Samples  Samples Cumulative  Negative  Negative Cumulative  \
# 0  2020-03-13       60                 639        80                  540
# 1  2020-03-14       92                 731        50                  590
# 2  2020-03-15      131                 862        19                  609
# 3  2020-03-16       33                 895        86                  695
# 4  2020-03-17       48                 943        71                  766
#
#    Positive  Positive Cumulative
# 0         0                    6
# 1         0                    6
# 2         0                    6
# 3         1                    7
# 4         4                   11

# %%
import datetime as dt
data['Date_num'] = pd.to_datetime(data['Date'])

# %%
data['Date_num']=data['Date_num'].map(dt.datetime.toordinal)

# %%
data.head()
# Out:
#          Date  Samples  Samples Cumulative  Negative  Negative Cumulative  \
# 0  2020-03-13       60                 639        80                  540
# 1  2020-03-14       92                 731        50                  590
# 2  2020-03-15      131                 862        19                  609
# 3  2020-03-16       33                 895        86                  695
# 4  2020-03-17       48                 943        71                  766
#
#    Positive  Positive Cumulative  Date_num
# 0         0                    6    737497
# 1         0                    6    737498
# 2         0                    6    737499
# 3         1                    7    737500
# 4         4                   11    737501

# %%
X = data['Date_num'].values.reshape(-1,1)

# %%
Y=data['Positive Cumulative'].values.reshape(-1,1)

# %%
data
# Out:
#           Date  Samples  Samples Cumulative  Negative  Negative Cumulative  \
# 0   2020-03-13       60                 639        80                  540
# 1   2020-03-14       92                 731        50                  590
# 2   2020-03-15      131                 862        19                  609
# 3   2020-03-16       33                 895        86                  695
# 4   2020-03-17       48                 943        71                  766
# 5   2020-03-18      125                1068       103                  869
# 6   2020-03-19       75                1143        46                  915
# 7   2020-03-20       64                1207        55                  970
# 8   2020-03-21      170                1377        26                  996
# 9   2020-03-22       10                1387       112                 1108
# 10  2020-03-23       96                1477        45                 1153
# 11  2020-03-24      160                1637        43                 1196
# 12  2020-03-25      278                2438       175                 2242
# 13  2020-03-26      293                2731       190                 2432
# 14  2020-03-27      237                2838       150                 2563
# 15  2020-03-28      195                3076       141                 2763
# 16  2020-03-29      179                3170       229                 2874
# 17  2020-03-30      172                3242       207                 3025
# 18  2020-03-31      206                3535       198                 3297
# 19  2020-04-01      244                3799       182                 3479
# 20  2020-04-02      384                4181       235                 3910
# 21  2020-04-03      344                4587       321                 4281
# 22  2020-04-04      400                5061       304                 4566
# 23  2020-04-05      482                5543       471                 5037
# 24  2020-04-06      325                5958       324                 5503
# 25  2020-04-07      617                6580       437                 5942
# 26  2020-04-08      516                6967       424                 6473
# 27  2020-04-09      572                7613       656                 7176
# 28  2020-04-10      574                7975       497                 7673
# 29  2020-04-11      585                8560       558                 8231
#
#     Positive  Positive Cumulative  Date_num
# 0          0                    6    737497
# 1          0                    6    737498
# 2          0                    6    737499
# 3          1                    7    737500
# 4          4                   11    737501
# 5          3                   14    737502
# 6          1                   15    737503
# 7          0                   15    737504
# 8          5                   20    737505
# 9          6                   26    737506
# 10         7                   33    737507
# 11         8                   41    737508
# 12        10                   51    737509
# 13         4                   55    737510
# 14         9                   64    737511
# 15        12                   76    737512
# 16         7                   83    737513
# 17         5                   88    737514
# 18        13                  101    737515
# 19         9                  110    737516
# 20        14                  124    737517
# 21         4                  128    737518
# 22        16                  144    737519
# 23         7                  151    737520
# 24        12                  163    737521
# 25        12                  175    737522
# 26         6                  181    737523
# 27        16                  197    737524
# 28        10                  207    737525
# 29         8                  215    737526

# %%
regressor = LinearRegression()

# %%
regressor.fit(X,Y)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X)

# %%
plt.figure(figsize=(20,10))
plt.scatter(data.Date, Y, color = 'magenta')
plt.plot(data.Date, y_pred, color = 'green')
plt.xticks(rotation=45)
plt.title('Daywise confirmed case in Karnataka')
plt.xlabel('Date wise')
plt.ylabel('Confirmed case')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree = 2)

# %%
X_poly = poly.fit_transform(X)
regressor = LinearRegression()
regressor.fit(X_poly,Y)
y_poly_pred=regressor.predict(X_poly)

# %%
plt.figure(figsize=(20,10))
plt.scatter(data.Date, Y, color = 'magenta')
plt.plot(data.Date, y_poly_pred, color = 'green')
plt.xticks(rotation=45)
plt.title('Daywise confirmed case in Karnataka')
plt.xlabel('Date wise')
plt.ylabel('Confirmed Cases')
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(Y,y_poly_pred))
r2 = r2_score(Y,y_poly_pred)
print('RMSE is ' + str(rmse))
print('r2 is ' +str(r2))
# Out:
# RMSE is 4.00806150851938
# r2 is 0.9965534434571387

# %%
regressor.predict(poly.fit_transform([[6.5]]))
# Out:
# array([[1.12053252e+11]])

# %%
regressor.coef_
# Out:
# array([[ 0.00000000e+00, -3.03881554e+05,  2.06023408e-01]])
